# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
nw_list = [100,1000,10000,100000,1000000]
nw_arr=np.array(nw_list)
L_list=[200,100,20,10]
E_bethe_list=[]
e_nw_vs_L=[]

# %% [markdown]
# # L = 200

# %%
E_bethe = -88.6335532522416
E_bethe_list.append(E_bethe)
E_bethe_list
# Out:
# [-88.6335532522416]

# %%
data_dir = os.path.join('L_200/')
nw_l = []
enw = []
enw_err = []

#max projection lenght to trust
pfix = 30 
#max p.l. to plot 
maxP = 100


for nw in nw_list:
    energy_list =[]
    err_list = []
    p_list = []
    count = 0
    with open(os.path.join(data_dir + 'L200_nw{}.dat'.format(nw)),'r') as f:
        for line in f: 
            count +=1 
            data = [ float(x.strip('\n')) for x in line.split('\t') if x.strip('')]
            p_list.append(data[0])
            energy_list.append(data[1])
            err_list.append(data[2])
            if count == pfix: 
                nw_l.append(1.0/nw)
                enw.append(data[1])
                enw_err.append(data[2])
    plt.figure(figsize=(8,5))
    plt.xlabel('Projection lenght p',fontsize = 12)
    plt.ylabel('Energy',fontsize = 12)
    plt.xlim(0,maxP)
    plt.xticks(range(0,maxP + 1,10))
    plt.errorbar(p_list,energy_list,yerr = err_list, color = 'black',label = 'nw = {}'.format(nw))
    plt.hlines(E_bethe,1,maxP,color = 'red', label = 'Bethe ansatz')
    plt.legend(fontsize = 12)
    plt.show()
e_nw_vs_L.append(enw)
#print(e_nw_vs_L)

# %%
energy_list =[]
err_list = []
p_list = []
with open(os.path.join(data_dir + 'L200_1mil_bin300.dat'),'r') as f:
    for line in f: 
        data = [ float(x.strip('\n')) for x in line.split('\t') if x.strip('')]
        p_list.append(data[0])
        energy_list.append(data[1])
        err_list.append(data[2])
plt.figure(figsize=(8,5))
plt.xlabel('Projection lenght p',fontsize = 12)
plt.ylabel('Energy',fontsize = 12)
plt.xlim(0,maxP)
plt.xticks(range(0,maxP + 1,10))
plt.errorbar(p_list,energy_list,yerr = err_list, color = 'black',label = 'nw = {}'.format(nw))
plt.hlines(E_bethe,1,maxP,color = 'red', label = 'Bethe ansatz')
plt.legend(fontsize = 12)
plt.show()

# %% [markdown]
# Let's fix the projection time $p = 30$ ( notice that $ p \times n_{bra} = 150$ ) and plot the energy as a function of $ 1/ N_w$.

# %%
plt.figure(figsize=(8,5))
plt.xlabel(r'$ 1 / N_w$',fontsize = 12)
plt.ylabel('Energy',fontsize = 12)
plt.errorbar(nw_l,enw,yerr = enw_err,fmt = '*', color = 'black',label = r'Energy ($p = 30$)')
plt.plot(nw_l, enw, linewidth = 0.3,color ='black')
plt.hlines(E_bethe,0.0,0.01,color = 'red', label = 'Bethe ansatz')
plt.legend(fontsize = 12)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.xlabel(r'$ 1 / N_w$',fontsize = 12)
plt.xscale('log')
plt.ylabel('Energy',fontsize = 12)
plt.errorbar(nw_l,enw,yerr = enw_err,fmt = '*', color = 'black',label = r'Energy ($p = 30$)')
plt.plot(nw_l, enw, linewidth = 0.3,color ='black')
plt.hlines(E_bethe,0.0,0.01,color = 'red', label = 'Bethe ansatz')
plt.legend(fontsize = 12)
plt.show()

# %% [markdown]
#  # L=100

# %%
E_bethe =  -44.3229570750919
E_bethe_list.append(E_bethe)
E_bethe_list
# Out:
# [-88.6335532522416, -44.3229570750919]

# %%
data_dir = os.path.join('L_100/')
nw_l = []
enw = []
enw_err = []

#max projection lenght to trust
pfix = 30 
#max p.l. to plot 
maxP = 100


for nw in nw_list:
    energy_list =[]
    err_list = []
    p_list = []
    count = 0
    with open(os.path.join(data_dir + '{}.nw/dmc_en.dat'.format(nw)),'r') as f:
        for line in f: 
            count +=1 
            data = [ float(x.strip('\n')) for x in line.split('\t') if x.strip('')]
            p_list.append(data[0])
            energy_list.append(data[1])
            err_list.append(data[2])
            if count == pfix: 
                nw_l.append(1.0/nw)
                enw.append(data[1])
                enw_err.append(data[2])
    plt.figure(figsize=(8,5))
    plt.xlabel('Projection lenght p',fontsize = 12)
    plt.ylabel('Energy',fontsize = 12)
    plt.xlim(0,maxP)
    plt.xticks(range(0,maxP + 1,10))
    plt.errorbar(p_list,energy_list,yerr = err_list, color = 'black',label = 'nw = {}'.format(nw))
    plt.hlines(E_bethe,1,maxP,color = 'red', label = 'Bethe ansatz')
    plt.legend(fontsize = 12)
    plt.show()
e_nw_vs_L.append(enw)

# %%
energy_list =[]
err_list = []
p_list = []
with open(os.path.join(data_dir + 'dmc_en.dat'),'r') as f:
    for line in f: 
        data = [ float(x.strip('\n')) for x in line.split('\t') if x.strip('')]
        p_list.append(data[0])
        energy_list.append(data[1])
        err_list.append(data[2])
maxP=300
plt.figure(figsize=(8,5))
plt.xlabel('Projection lenght p',fontsize = 12)
plt.ylabel('Energy',fontsize = 12)
plt.xlim(0,maxP)
plt.xticks(range(0,maxP + 1,30))
plt.errorbar(p_list,energy_list,yerr = err_list, color = 'black',label = 'nw = {}'.format(nw))
plt.hlines(E_bethe,1,maxP,color = 'red', label = 'Bethe ansatz')
plt.legend(fontsize = 12)
plt.show()

# %% [markdown]
# Let's fix the projection time $p = 30$ ( notice that $ p \times n_{bra} = 150$ ) and plot the energy as a function of $ 1/ N_w$.

# %%
plt.figure(figsize=(8,5))
plt.xlabel(r'$ 1 / N_w$',fontsize = 12)
plt.ylabel('Energy',fontsize = 12)
plt.errorbar(nw_l,enw,yerr = enw_err,fmt = '*', color = 'black',label = r'Energy ($p = 30$)')
plt.plot(nw_l, enw, linewidth = 0.3,color ='black')
plt.hlines(E_bethe,0.0,0.01,color = 'red', label = 'Bethe ansatz')
plt.legend(fontsize = 12)
plt.show()
plt.figure(figsize=(8,5))
plt.xlabel(r'$ 1 / N_w$',fontsize = 12)
plt.xscale('log')
plt.ylabel('Energy',fontsize = 12)
plt.errorbar(nw_l,enw,yerr = enw_err,fmt = '*', color = 'black',label = r'Energy ($p = 30$)')
plt.plot(nw_l, enw, linewidth = 0.3,color ='black')
plt.hlines(E_bethe,0.0,0.01,color = 'red', label = 'Bethe ansatz')
plt.legend(fontsize = 12)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
nw_list = [100,500,1000,5000,10000,50000,100000,1000000]

# %% [markdown]
# # L = 20

# %%
E_bethe = -8.90438652987644
E_bethe_list.append(E_bethe)
E_bethe_list
# Out:
# [-88.6335532522416,
#  -44.3229570750919,
#  -8.90438652987644,
#  -4.51544635449204,
#  -8.90438652987644]

# %%
data_dir = os.path.join('L_20/')
nw_l = []
enw = []
enw_err = []

#max projection lenght to trust
pfix = 30 
#max p.l. to plot 
maxP = 100


for nw in nw_list:
    energy_list =[]
    err_list = []
    p_list = []
    count = 0
    with open(os.path.join(data_dir + 'L20_nw{}.dat'.format(nw)),'r') as f:
        for line in f: 
            count +=1 
            data = [ float(x.strip('\n')) for x in line.split('\t') if x.strip('')]
            p_list.append(data[0])
            energy_list.append(data[1])
            err_list.append(data[2])
            if count == pfix: 
                nw_l.append(1.0/nw)
                enw.append(data[1])
                enw_err.append(data[2])
    plt.figure(figsize=(8,5))
    plt.xlabel('Projection lenght p',fontsize = 12)
    plt.ylabel('Energy',fontsize = 12)
    plt.xlim(0,maxP)
    plt.xticks(range(0,maxP + 1,10))
    plt.errorbar(p_list,energy_list,yerr = err_list, color = 'black',label = 'nw = {}'.format(nw))
    plt.hlines(E_bethe,1,maxP,color = 'red', label = 'Bethe ansatz')
    plt.legend(fontsize = 12)
    plt.show()
e_nw_vs_L.append(enw)

# %%
energy_list =[]
err_list = []
p_list = []
with open(os.path.join(data_dir + 'L20_1mil_bin300.dat'),'r') as f:
    for line in f: 
        data = [ float(x.strip('\n')) for x in line.split('\t') if x.strip('')]
        p_list.append(data[0])
        energy_list.append(data[1])
        err_list.append(data[2])
plt.figure(figsize=(8,5))
plt.xlabel('Projection lenght p',fontsize = 12)
plt.ylabel('Energy',fontsize = 12)
plt.xlim(0,maxP)
plt.xticks(range(0,maxP + 1,10))
plt.errorbar(p_list,energy_list,yerr = err_list, color = 'black',label = 'nw = {}'.format(nw))
plt.hlines(E_bethe,1,maxP,color = 'red', label = 'Bethe ansatz')
plt.legend(fontsize = 12)
plt.show()

# %% [markdown]
# Let's fix the projection time $p = 30$ ( notice that $ p \times n_{bra} = 150$ ) and plot the energy as a function of $ 1/ N_w$.

# %%
plt.figure(figsize=(8,5))
plt.xlabel(r'$ 1 / N_w$',fontsize = 12)
plt.ylabel('Energy',fontsize = 12)
plt.errorbar(nw_l,enw,yerr = enw_err,fmt = '*', color = 'black',label = r'Energy ($p = 30$)')
plt.plot(nw_l, enw, linewidth = 0.3,color ='black')
plt.hlines(E_bethe,0.0,0.01,color = 'red', label = 'Bethe ansatz')
plt.legend(fontsize = 12)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.xlabel(r'$ 1 / N_w$',fontsize = 12)
plt.xscale('log')
plt.ylabel('Energy',fontsize = 12)
plt.errorbar(nw_l,enw,yerr = enw_err,fmt = '*', color = 'black',label = r'Energy ($p = 30$)')
plt.plot(nw_l, enw, linewidth = 0.3,color ='black')
plt.hlines(E_bethe,0.0,0.01,color = 'red', label = 'Bethe ansatz')
plt.legend(fontsize = 12)
plt.show()

# %% [markdown]
# # L = 10

# %%
nw_list = [100,1000,10000,100000,1000000]

# %%
E_bethe =  -4.51544635449204
E_bethe_list.append(E_bethe)
E_bethe_list
# Out:
# [-88.6335532522416, -44.3229570750919, -8.90438652987644, -4.51544635449204]

# %%
data_dir = os.path.join('L_10/')
nw_l = []
enw = []
enw_err = []

#max projection lenght to trust
pfix = 30 
#max p.l. to plot 
maxP = 100


for nw in nw_list:
    energy_list =[]
    err_list = []
    p_list = []
    count = 0
    with open(os.path.join(data_dir + 'L10_nw{}.dat'.format(nw)),'r') as f:
        for line in f: 
            count +=1 
            data = [ float(x.strip('\n')) for x in line.split('\t') if x.strip('')]
            p_list.append(data[0])
            energy_list.append(data[1])
            err_list.append(data[2])
            if count == pfix: 
                nw_l.append(1.0/nw)
                enw.append(data[1])
                enw_err.append(data[2])
    plt.figure(figsize=(8,5))
    plt.xlabel('Projection lenght p',fontsize = 12)
    plt.ylabel('Energy',fontsize = 12)
    plt.xlim(0,maxP)
    plt.xticks(range(0,maxP + 1,10))
    plt.errorbar(p_list,energy_list,yerr = err_list, color = 'black',label = 'nw = {}'.format(nw))
    plt.hlines(E_bethe,1,maxP,color = 'red', label = 'Bethe ansatz')
    plt.legend(fontsize = 12)
    plt.show()
e_nw_vs_L.append(enw)

# %%
plt.figure(figsize=(8,5))
plt.xlabel(r'$ 1 / N_w$',fontsize = 12)
plt.ylabel('Energy',fontsize = 12)
plt.errorbar(nw_l,enw,yerr = enw_err,fmt = '*', color = 'black',label = r'Energy ($p = 30$)')
plt.plot(nw_l, enw, linewidth = 0.3,color ='black')
plt.hlines(E_bethe,0.0,0.01,color = 'red', label = 'Bethe ansatz')
plt.legend(fontsize = 12)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.xlabel(r'$ 1 / N_w$',fontsize = 12)
plt.xscale('log')
plt.ylabel('Energy',fontsize = 12)
plt.errorbar(nw_l,enw,yerr = enw_err,fmt = '*', color = 'black',label = r'Energy ($p = 30$)')
plt.plot(nw_l, enw, linewidth = 0.3,color ='black')
plt.hlines(E_bethe,0.0,0.01,color = 'red', label = 'Bethe ansatz')
plt.legend(fontsize = 12)
plt.show()

# %%
#print(E_bethe_list,L_list,e_nw_vs_L)
#fisso un numero di walker 1milione
for i in range(len(L_list)):
    L_array=np.array(L_list)
    e_nw_L_arr=np.array(e_nw_vs_L)
    print(e_nw_L_arr.shape)
    E_bethe_arr=np.array(E_bethe_list)
    nw_arr=np.array([100,1000,10000,100000,1000000])
    e_rel=np.empty(len(L_array))
    e_rel[:]=np.abs((e_nw_L_arr[:,i]-E_bethe_arr[:])/E_bethe_arr[:])
    print(e_rel)
    plt.plot(np.log(L_array),np.log(e_rel),label=" nw={}".format(nw_arr[i]))

    plt.legend()
plt.ylabel("log(err_rel)")
plt.xlabel("log(L)")
plt.savefig("convergence_and_size.pdf")
plt.show()
# Out:
# (4, 5)
# [0.04758455 0.01771941 0.00420185 0.00245082]
# (4, 5)
# [0.02487652 0.00558365 0.00016321 0.0002825 ]
# (4, 5)
# [6.93959618e-03 1.35996964e-03 3.52650507e-05 3.06128147e-06]
# (4, 5)
# [5.33118116e-03 3.96916022e-04 1.86099434e-05 1.97057886e-05]

# %%
print((e_nw_L_arr[:,4]-E_bethe_arr[:])/E_bethe_arr[:])
# Out:
# [-6.20731877e-04  2.16193332e-05 -1.24370194e-05 -7.54590836e-06]
